# %% [markdown]
#  Assignment-2

# %% [markdown]
# ## Q1. How do you comment code in Python? What are the different types of comments?

# %%
#In Python,comments are used to explain code and make it easier to understand.

# Single-line comment example
print('Hello')
# Multi-line comment
"""
This is a multi-line comment
used to explain code
"""
print("Hello")

# %% [markdown]
# ## Q2. What are variables in Python? How do you declare and assign values to variables?

# %%
# A variable is used to store data in Python.
x = 10
name = 'Prachi'
price = 5.5
print(x, name, price)

# %% [markdown]
# ## Q3. How do you convert one data type to another in Python?

# %%
a = '10'
b = int(a)
print(b)

# %% [markdown]
# ## Q4. How do you write and execute a Python script from the command line?

# %%
# Example python script
print('Hello World')

# %% [markdown]
# ## Q5. Given a list my_list = [1,2,3,4,5], obtain sub-list [2,3]

# %%
my_list = [1,2,3,4,5]
sub_list = my_list[1:3]
print(sub_list)

# %% [markdown]
# ## Q6. What is a complex number and how is it represented in Python?

# %%
num = 3 + 4j
print(num)

# %% [markdown]
# ## Q7. What is the correct way to declare a variable named age and assign the value 25 to it?

# %%
age = 25
print(age)

# %% [markdown]
# ## Q8. Declare a variable named price and assign the value 9.99 to it. What data type does it belong to?

# %%
price = 9.99
print(type(price))

# %% [markdown]
# ## Q9. Create a variable named name and assign your full name to it as a string. Print it.

# %%
name = 'Prachi Vadhnani'
print(name)

# %% [markdown]
# ## Q10. Given the string 'Hello, World!', extract the substring 'World'.

# %%
text = 'Hello, World!'
result = text[7:12]
print(result)

# %% [markdown]
# ## Q11. Create a variable named is_student and assign it a boolean value.

# %%
is_student = True
print(is_student)
